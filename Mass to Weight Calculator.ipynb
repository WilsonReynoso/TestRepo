# %% [markdown]
# This code takes inputs of mass in pounds and converts the input into weight in Newtons

# %%
pounds=int(input("What is your mass in pounds?\n"))
kg=pounds/2.024
g=9.81
weight=kg*g
print("your weight is:",round(weight,2))
# Out:
# What is your mass in pounds?
#  55
# your weight is: 266.58
